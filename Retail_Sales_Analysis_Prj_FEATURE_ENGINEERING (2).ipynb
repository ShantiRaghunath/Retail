# %% [markdown]
# # Package Installation for Snowflake Connection and Data Processing

# %%
# !pip install  dask[complete]  snowflake  snowflake-connector-python snowflake-snowpark-python snowflake-snowpark-python[pandas] seaborn matplotlib numpy pandas scikit-learn  fosforml plotly
# Out:
# Requirement already satisfied: dask[complete] in /opt/conda/lib/python3.9/site-packages (2024.8.0)
# Requirement already satisfied: snowflake in /opt/conda/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: snowflake-connector-python in /opt/conda/lib/python3.9/site-packages (3.12.2)
# Requirement already satisfied: snowflake-snowpark-python in /opt/conda/lib/python3.9/site-packages (1.22.1)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: fosforml in /opt/conda/lib/python3.9/site-packages (1.1.8)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.9/site-packages (5.24.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (2023.12.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (24.1)
# Requirement already satisfied: importlib-metadata>=4.13.0; python_version < "3.12" in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (8.2.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (2.2.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (6.0.1)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (1.4.2)
# Requirement already satisfied: click>=8.1 in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (8.1.7)
# Requirement already satisfied: lz4>=4.3.2; extra == "complete" in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (4.3.3)
# Requirement already satisfied: pyarrow-hotfix; extra == "complete" in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (0.6)
# Requirement already satisfied: pyarrow>=7.0; extra == "complete" in /opt/conda/lib/python3.9/site-packages (from dask[complete]) (17.0.0)
# Requirement already satisfied: snowflake-core==0.12.1 in /opt/conda/lib/python3.9/site-packages (from snowflake) (0.12.1)
# Requirement already satisfied: snowflake-legacy in /opt/conda/lib/python3.9/site-packages (from snowflake) (0.12.1)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (24.0.0)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (42.0.5)
# Requirement already satisfied: urllib3<2.0.0,>=1.21.1; python_version < "3.10" in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (1.26.20)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (2.9.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: requests<3.0.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (2024.7.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: tomlkit in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (0.13.2)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (4.12.2)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (3.16.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (1.16.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python) (4.2.2)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python) (0.37.1)
# Requirement already satisfied: setuptools>=40.6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python) (65.6.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /opt/conda/lib/python3.9/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: snowflake-ml-python==1.5.0; python_version <= "3.9" in /opt/conda/lib/python3.9/site-packages (from fosforml) (1.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata>=4.13.0; python_version < "3.12"->dask[complete]) (3.19.2)
# Requirement already satisfied: locket in /opt/conda/lib/python3.9/site-packages (from partd>=1.4.0->dask[complete]) (1.0.0)
# Requirement already satisfied: atpublic>=4 in /opt/conda/lib/python3.9/site-packages (from snowflake-core==0.12.1->snowflake) (5.0)
# Requirement already satisfied: pydantic>=2 in /opt/conda/lib/python3.9/site-packages (from snowflake-core==0.12.1->snowflake) (2.9.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: cachetools<6,>=3.1.1 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (5.5.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (3.7.1)
# Requirement already satisfied: s3fs<2024,>=2022.11 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (2023.12.2)
# Requirement already satisfied: catboost<1.3,>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.2.7)
# Requirement already satisfied: absl-py<2,>=0.15 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.4.0)
# Requirement already satisfied: sqlparse<1,>=0.4 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (0.5.1)
# Requirement already satisfied: pytimeparse<2,>=1.1.8 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.1.8)
# Requirement already satisfied: retrying<2,>=1.3.3 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.3.4)
# Requirement already satisfied: xgboost<2,>=1.7.3 in /opt/conda/lib/python3.9/site-packages (from snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.7.6)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.9/site-packages (from pydantic>=2->snowflake-core==0.12.1->snowflake) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.9/site-packages (from pydantic>=2->snowflake-core==0.12.1->snowflake) (0.7.0)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.3.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.9/site-packages (from s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (2.15.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.9/site-packages (from s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (3.10.8)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.9/site-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (0.20.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (0.12.0)
# Requirement already satisfied: botocore<1.35.24,>=1.35.16 in /opt/conda/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.35.23)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.9/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (23.2.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (2.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (6.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.4.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from botocore<1.35.24,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python==1.5.0; python_version <= "3.9"->fosforml) (1.0.1)
# WARNING: You are using pip version 19.3.1; however, version 24.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Import necessary libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from plotly import express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Set display options for better output visibility
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # This section connects to Snowflake using **fosforml's Snowflake session manager**, retrieves data from a specified Snowflake table, and loads the data into a Pandas DataFrame for further processing and modeling.

# %%
# Import the get_session function from fosforml's Snowflake session manager
# This function helps in establishing a Snowflake session for executing queries
from fosforml.model_manager.snowflakesession import get_session

# Establish a Snowflake session using the configured session manager
# The session will allow you to execute SQL queries and retrieve data from Snowflake
my_session = get_session()

#  Define the name of the table you want to query from Snowflake
# This table should contain the data for order statuses, including DELIVERED, IN PROCESS, CANCELLED, and RETURNED orders
table_name = 'ORDER_DATA_FINAL'

#  Execute a SQL query to select all records from the specified Snowflake table
# The data is retrieved from Snowflake and loaded into a Pandas DataFrame for further processing
df = my_session.sql(f"SELECT * FROM {table_name}").to_pandas()

# Display the first few rows of the retrieved DataFrame to verify the data load
df.head()
# Out:
#   DIVISION_CODE     DIVISION_NAME BRAND_CODE    BRAND_NAME CLASS_CODE  \
# 0            18  Intimate Apparel      11630         Falke        117
# 1            11   Women's Apparel      15332           TSE          2
# 2            11   Women's Apparel      11685   Elie Tahari          4
# 3            11   Women's Apparel      45644    LK Bennett        124
# 4            56           Jewelry      13823  NEST Jewelry         40
#
#   CLASS_NAME SELLING_CHANNEL   CHAIN WEB_ORDER_NUMBER  OMS_ORDER_NUMBER  \
# 0      Socks          Online  Chain2   WC200001283027          51944671
# 1   Sweaters          Online  Chain1   WC100004199018          51986531
# 2      Pants          Online  Chain1   WC100004151518          51905876
# 3      Dress          Online  Chain1   WC100004179746          51953152
# 4      Rings          Online  Chain1   WC100004190179          51970366
#
#   OMS_LINE_ITEM_ID OMS_TICKET_ID        SKU_ID  QUANTITY  UNIT_PRICE  \
# 0       51944671*1    51944671-1  301224807145         2        20.0
# 1       51986531*2    51986531-2  301231641008         1       130.0
# 2       51905876*3    51905876-3  301237540220         1       295.0
# 3       51953152*3    51953152-3  301238523284         1       495.0
# 4       51970366*1    51970366-1  301208806164         1        95.0
#
#   CURRENT_STATUS CURRENT_STATUS_DESCRIPTION TRANSACTION_DATE  \
# 0             VS                    Shipped       07-03-2024
# 1             CX                  Cancelled       11-03-2024
# 2             VS                    Shipped       04-03-2024
# 3             VS                    Shipped       08-03-2024
# 4             VS                    Shipped       08-03-2024
#
#    SHIP_FROM_WAREHOUSE_CODE SHIP_FROM_WAREHOUSE_DESCRIPTION ORDER_DATE  \
# 0                         5                        Oakbrook 2024-03-29
# 1                         5                        Oakbrook 2024-02-17
# 2                         5                        Oakbrook 2024-03-23
# 3                         5                        Oakbrook 2024-08-15
# 4                         5                        Oakbrook 2023-03-20
#
#   READY_TO_PRINT_DATE   PRINT_TICKET_DATE VERIFIED_SHIPPED_DATE  \
# 0 2024-03-06 13:00:00 2024-03-06 13:00:00   2024-03-07 11:01:23
# 1 2024-03-10 20:00:52 2024-03-09 13:00:00                   NaT
# 2 2024-03-02 13:00:00 2024-03-02 13:00:00   2024-03-04 15:02:27
# 3 2024-03-06 13:00:00 2024-03-06 13:00:00   2024-03-08 05:01:39
# 4 2024-03-08 13:00:00 2024-03-08 13:00:00   2024-03-08 13:01:33
#
#   BACK_ORDERED_DATE  ORDER_AGE  GIFT_ARTICLE_FLAG CARRIER_NAME  \
# 0              None          1              False        FedEx
# 1        10-03-2024          2              False         None
# 2              None          2              False        FedEx
# 3              None          2              False        FedEx
# 4              None          0              False        FedEx
#
#   CARRIER_TRACKING_NUMBER DROPSHIP_FLAG ORDER_STATUS ORDER_CREATION_DATE  \
# 0            ******597111          true         None                 NaT
# 1                    None         false         None                 NaT
# 2            ******422423          true         None                 NaT
# 3            ******853960          true         None                 NaT
# 4            ******885942          true         None                 NaT
#
#   ORDER_CONFIRMATION_DATE WM_ORDER_ID WM_ORDER_LINE_ID WM_ORDER_STATUS  \
# 0                     NaT        None             None            None
# 1                     NaT        None             None            None
# 2                     NaT        None             None            None
# 3                     NaT        None             None            None
# 4                     NaT        None             None            None
#
#   WM_PICKING_START_TIME WM_PICKING_END_TIME  WM_PICKING_AGE  \
# 0                   NaT                 NaT             NaN
# 1                   NaT                 NaT             NaN
# 2                   NaT                 NaT             NaN
# 3                   NaT                 NaT             NaN
# 4                   NaT                 NaT             NaN
#
#   WM_PACKING_START_TIME WM_PACKING_END_TIME  WM_PACKING_AGE WM_CREATED_DATE  \
# 0                   NaT                 NaT             NaN             NaT
# 1                   NaT                 NaT             NaN             NaT
# 2                   NaT                 NaT             NaN             NaT
# 3                   NaT                 NaT             NaN             NaT
# 4                   NaT                 NaT             NaN             NaT
#
#   WM_UPDATED_DATE WM_SHIPPED_DATE  WM_ORDER_AGE  STORE_ID STORE_NAME  \
# 0             NaT      2024-03-29           NaN       NaN         NA
# 1             NaT      2024-02-17           NaN    6247.0         NA
# 2             NaT      2024-03-23           NaN       NaN         NA
# 3             NaT      2024-08-15           NaN       NaN         NA
# 4             NaT      2023-03-20           NaN       NaN         NA
#
#   SHIP_METHOD_CODE            SHIP_METHOD_NAME SHIP_METHOD_SERVICE  \
# 0            FEDXH         FedEx Home Delivery              GROUND
# 1             None                        None              GROUND
# 2               ON  FedEx - Standard Overnight           OVERNIGHT
# 3            FEDXH         FedEx Home Delivery              GROUND
# 4            FEDXH         FedEx Home Delivery              GROUND
#
#    SHIPMENT_SLA NEW_ORDER_DATE RETURN_REASON RETURN_FLAG RECORD_DATE  \
# 0           NaN     2022-12-27          None        None        None
# 1           NaN     2023-05-07          None        None        None
# 2           NaN     2022-10-19          None        None        None
# 3           NaN     2022-10-09          None        None        None
# 4           NaN     2022-09-16          None        None        None
#
#   RECORD_TIME  GROSS_SALES RETURNED_STATUS  SHIPPING_DELAY PREDICTION_RESULT
# 0        None           40       DELIVERED           False                 1
# 1        None          130       CANCELLED           False                 1
# 2        None          295       DELIVERED           False                 0
# 3        None          495       DELIVERED           False                 1
# 4        None           95       DELIVERED           False                 0

# %%
df['RETURNED_STATUS'].value_counts()
# Out:
# RETURNED_STATUS
# DELIVERED     759943
# RETURNED       94089
# CANCELLED      62752
# IN PROCESS      9860
# Name: count, dtype: int64

# %%
df_sample = df[df['RETURNED_STATUS'].isin(['CANCELLED', 'RETURNED', 'DELIVERED', 'IN PROCESS'])]
df_sample = df.groupby('RETURNED_STATUS').sample(n=10000, replace=True)
df_sample
# Out:
#        DIVISION_CODE         DIVISION_NAME BRAND_CODE          BRAND_NAME  \
# 692563            18      Intimate Apparel      10332              Natori
# 330822            44                 Men's      11697       Robert Graham
# 810572            53                Beauty      11530                Dior
# 658745            81  Women's Designer RTW      12587         JW Anderson
# 567439            53                Beauty      11303               CREED
# ...              ...                   ...        ...                 ...
# 659119            34          Ladies Shoes      10538     Badgley Mischka
# 462406            36   Fashion Accessories      11552       Dolce&Gabbana
# 460914            34          Ladies Shoes      20266       Carrie Forbes
# 526514            35     Designer Handbags      10864  Brunello Cucinelli
# 582128            36   Fashion Accessories      11778           Valentino
#
#        CLASS_CODE        CLASS_NAME SELLING_CHANNEL   CHAIN  \
# 692563         42              Bras          Others  Chain1
# 330822          1       Shirts/Tops          Online  Chain1
# 810572        995             GWP's          Online  Chain1
# 658745          1       Shirts/Tops          Online  Chain2
# 567439        312         Fragrance          Online  Chain2
# ...           ...               ...             ...     ...
# 659119         60  Ballerinas/Flats          Online  Chain1
# 462406         89        Sunglasses          Others  Chain1
# 460914         54           Sandals          Online  Chain1
# 526514         20              Tote          Online  Chain1
# 582128        877             Belts          Online  Chain2
#
#           WEB_ORDER_NUMBER  OMS_ORDER_NUMBER OMS_LINE_ITEM_ID OMS_TICKET_ID  \
# 692563          CC62214473          52214473       52214473*2          None
# 330822      WC100004273290          52100687       52100687*6    52100687-5
# 810572      WC100004282119          52113042       52113042*6          None
# 658745      WC200001330323          52301706       52301706*1    52301706-1
# 567439      WC200001278989          51922351       51922351*1    51922351-1
# ...                    ...               ...              ...           ...
# 659119      WC100004315568          52162486       52162486*5    52162486-1
# 462406  STA000000000543227          51926106       51926106*2    51926106-1
# 460914      WC100004148691          51900443      51900443*10    51900443-2
# 526514      WC100004370191          52245250       52245250*4    52245250-1
# 582128      WC200001291564          51992306       51992306*2    51992306-1
#
#               SKU_ID  QUANTITY  UNIT_PRICE CURRENT_STATUS  \
# 692563  301077653920         1        72.0             CX
# 330822  301124167264         1       171.0             CX
# 810572  301227320795         1         0.0             CX
# 658745  301235168679         1       435.0             CX
# 567439  301235149364         1        81.0             CX
# ...              ...       ...         ...            ...
# 659119  301236874869        -1       198.0             RX
# 462406  301234595612        -1       345.0             RT
# 460914  301125196638        -1       242.0             RT
# 526514  301234950992        -1      3100.0             RT
# 582128  301233558410        -1      1350.0             RT
#
#        CURRENT_STATUS_DESCRIPTION TRANSACTION_DATE  SHIP_FROM_WAREHOUSE_CODE  \
# 692563                  Cancelled       26-03-2024                         6
# 330822                  Cancelled       20-03-2024                         5
# 810572                  Cancelled       19-03-2024                         5
# 658745                  Cancelled       04-04-2024                         3
# 567439                  Cancelled       04-03-2024                         3
# ...                           ...              ...                       ...
# 659119         Temp Return Credit       01-04-2024                         4
# 462406                   Returned       26-03-2024                         5
# 460914                   Returned       27-03-2024                         5
# 526514                   Returned       05-04-2024                         4
# 582128                   Returned       01-04-2024                         4
#
#        SHIP_FROM_WAREHOUSE_DESCRIPTION ORDER_DATE READY_TO_PRINT_DATE  \
# 692563                          STORES 2024-03-29                 NaT
# 330822                        Oakbrook 2024-09-08 2024-03-18 13:00:00
# 810572                        Oakbrook 2023-10-12                 NaT
# 658745                       Tampa Bay 2024-07-17 2024-04-03 13:00:00
# 567439                       Tampa Bay 2024-04-25 2024-03-04 13:00:00
# ...                                ...        ...                 ...
# 659119                          Denver 2024-07-25                 NaT
# 462406                        Oakbrook 2023-12-19 2024-03-04 14:03:37
# 460914                        Oakbrook 2024-06-12 2024-03-02 12:43:24
# 526514                          Denver 2023-12-20 2024-03-29 15:33:31
# 582128                          Denver 2024-07-27 2024-03-09 20:44:34
#
#          PRINT_TICKET_DATE VERIFIED_SHIPPED_DATE BACK_ORDERED_DATE  ORDER_AGE  \
# 692563                 NaT                   NaT              None          0
# 330822 2024-03-18 13:00:00                   NaT              None          2
# 810572                 NaT                   NaT              None          0
# 658745                 NaT                   NaT              None          1
# 567439                 NaT                   NaT              None          0
# ...                    ...                   ...               ...        ...
# 659119                 NaT                   NaT              None          9
# 462406 2024-03-05 09:07:27                   NaT              None         22
# 460914 2024-03-02 12:46:52                   NaT              None         25
# 526514 2024-03-29 16:17:00                   NaT              None          7
# 582128 2024-03-09 20:46:17                   NaT              None         23
#
#         GIFT_ARTICLE_FLAG     CARRIER_NAME CARRIER_TRACKING_NUMBER  \
# 692563              False            FedEx                    None
# 330822              False            FedEx                    None
# 810572               True             None                    None
# 658745              False      Need it Now                    None
# 567439              False            FedEx                    None
# ...                   ...              ...                     ...
# 659119              False            FedEx            ******095650
# 462406              False            FedEx            ******102371
# 460914              False            FedEx            ******677317
# 526514              False            FedEx            ******296390
# 582128              False  FedEx SmartPost    ******13642641303130
#
#        DROPSHIP_FLAG ORDER_STATUS ORDER_CREATION_DATE ORDER_CONFIRMATION_DATE  \
# 692563         false         None                 NaT                     NaT
# 330822          true         None                 NaT                     NaT
# 810572         false         None                 NaT                     NaT
# 658745         false           NA          1900-01-01              1900-01-01
# 567439         false           NA          1900-01-01              1900-01-01
# ...              ...          ...                 ...                     ...
# 659119          true         None                 NaT                     NaT
# 462406         false         None                 NaT                     NaT
# 460914         false         None                 NaT                     NaT
# 526514         false         None                 NaT                     NaT
# 582128         false         None                 NaT                     NaT
#
#        WM_ORDER_ID WM_ORDER_LINE_ID WM_ORDER_STATUS WM_PICKING_START_TIME  \
# 692563        None             None            None                   NaT
# 330822        None             None            None                   NaT
# 810572        None             None            None                   NaT
# 658745        None           ******      Not in MAO                   NaT
# 567439        None           ******      Not in MAO                   NaT
# ...            ...              ...             ...                   ...
# 659119        None             None            None                   NaT
# 462406        None             None            None                   NaT
# 460914        None             None            None                   NaT
# 526514        None             None            None                   NaT
# 582128        None             None            None                   NaT
#
#        WM_PICKING_END_TIME  WM_PICKING_AGE WM_PACKING_START_TIME  \
# 692563                 NaT             NaN                   NaT
# 330822                 NaT             NaN                   NaT
# 810572                 NaT             NaN                   NaT
# 658745                 NaT             NaN                   NaT
# 567439                 NaT             NaN                   NaT
# ...                    ...             ...                   ...
# 659119                 NaT             NaN                   NaT
# 462406                 NaT             NaN                   NaT
# 460914                 NaT             NaN                   NaT
# 526514                 NaT             NaN                   NaT
# 582128                 NaT             NaN                   NaT
#
#        WM_PACKING_END_TIME  WM_PACKING_AGE WM_CREATED_DATE WM_UPDATED_DATE  \
# 692563                 NaT             NaN             NaT             NaT
# 330822                 NaT             NaN             NaT             NaT
# 810572                 NaT             NaN             NaT             NaT
# 658745                 NaT             NaN      1900-01-01      1900-01-01
# 567439                 NaT             NaN      1900-01-01      1900-01-01
# ...                    ...             ...             ...             ...
# 659119                 NaT             NaN             NaT             NaT
# 462406                 NaT             NaN             NaT             NaT
# 460914                 NaT             NaN             NaT             NaT
# 526514                 NaT             NaN             NaT             NaT
# 582128                 NaT             NaN             NaT             NaT
#
#        WM_SHIPPED_DATE  WM_ORDER_AGE  STORE_ID STORE_NAME SHIP_METHOD_CODE  \
# 692563      2024-03-29           NaN       NaN         NA              SDD
# 330822      2024-09-08           NaN       NaN         NA            FEDXH
# 810572      2023-10-12           NaN       NaN         NA             None
# 658745      1900-01-01       -9999.0       NaN         NA            NDTN3
# 567439      1900-01-01       -9999.0       NaN         NA            FEDXH
# ...                ...           ...       ...        ...              ...
# 659119      2024-07-25           NaN    6088.0         NA            FEDXH
# 462406      2023-12-19           NaN    6247.0         NA            FEDXH
# 460914      2024-06-12           NaN    6247.0         NA            FEDXH
# 526514      2023-12-20           NaN    6088.0         NA            FEDXH
# 582128      2024-07-27           NaN    6088.0         NA            FXPOS
#
#            SHIP_METHOD_NAME SHIP_METHOD_SERVICE  SHIPMENT_SLA NEW_ORDER_DATE  \
# 692563        FedEx - 2 Day             2ND DAY           NaN     2023-09-29
# 330822  FedEx Home Delivery              GROUND           NaN     2023-01-18
# 810572                 None              GROUND           NaN     2022-10-21
# 658745          Need it Now              GROUND           NaN     2024-01-17
# 567439  FedEx Home Delivery              GROUND           NaN     2023-10-25
# ...                     ...                 ...           ...            ...
# 659119  FedEx Home Delivery              GROUND           NaN     2023-11-18
# 462406  FedEx Home Delivery              GROUND           NaN     2023-06-19
# 460914  FedEx Home Delivery              GROUND           NaN     2023-05-07
# 526514  FedEx Home Delivery              GROUND           NaN     2022-08-13
# 582128      FedEx SmartPost              GROUND           NaN     2024-01-27
#
#        RETURN_REASON         RETURN_FLAG RECORD_DATE      RECORD_TIME  \
# 692563          None                None        None             None
# 330822          None                None        None             None
# 810572          None                None        None             None
# 658745          None                None        None             None
# 567439          None                None        None             None
# ...              ...                 ...         ...              ...
# 659119  Changed Mind  Partially Returned  2024-10-01  04:23:00.597000
# 462406   Size Issues                None        None             None
# 460914   Size Issues                None        None             None
# 526514  Changed Mind                None        None             None
# 582128   Size Issues                None        None             None
#
#         GROSS_SALES RETURNED_STATUS  SHIPPING_DELAY PREDICTION_RESULT
# 692563           72       CANCELLED           False                 1
# 330822          171       CANCELLED           False                 1
# 810572            0       CANCELLED           False                 1
# 658745          435       CANCELLED           False                 1
# 567439           81       CANCELLED           False                 1
# ...             ...             ...             ...               ...
# 659119         -198        RETURNED           False                 1
# 462406         -345        RETURNED           False                 1
# 460914         -242        RETURNED           False                 1
# 526514        -3100        RETURNED           False                 1
# 582128        -1350        RETURNED           False                 1
#
# [40000 rows x 61 columns]

# %% [markdown]
# # Dictionary to map status codes to full forms

# %%
status_map = {
    'VS': 'Verified Shipped', 
    'RT': 'Ready to Ship',
    'CX': 'Cancelled', #cancelled #training columns
    'RX': 'Return to Sender',
    'BO': 'Backordered', #cancelled #training columns
    'PT': 'Print Ticket', #cancelled #training columns
    'DS': 'Drop Shipped', 
    'RN': 'Returned',
    'RP': 'Replacement',
    'CB': 'Chargeback', #cancelled #training columns
    'RD': 'Ready to Drop' #cancelled #training columns
}

# Replace the values in the CURRENT_STATUS column
df_sample['CURRENT_STATUS'] = df_sample['CURRENT_STATUS'].replace(status_map)

df_sample['CURRENT_STATUS'].value_counts()
# Out:
# CURRENT_STATUS
# Cancelled           10000
# Verified Shipped    10000
# Ready to Ship        8647
# Backordered          5424
# Print Ticket         2420
# Drop Shipped         1296
# Return to Sender     1276
# Replacement           744
# Returned               77
# Chargeback             74
# Ready to Drop          42
# Name: count, dtype: int64

# %% [markdown]
# # Converting Date Columns to Datetime Format with Error Handling

# %%
# List of columns that contain date-related data
date_columns = ['ORDER_DATE', 'TRANSACTION_DATE', 'VERIFIED_SHIPPED_DATE', 'READY_TO_PRINT_DATE', 
                'PRINT_TICKET_DATE', 'WM_PICKING_START_TIME', 'WM_PICKING_END_TIME', 'WM_SHIPPED_DATE']

#  Loop through each column in the list and convert it to a datetime object
for col in date_columns:
    # Convert each column to datetime, using 'coerce' to handle errors in formatting
    df_sample[col] = pd.to_datetime(df_sample[col], errors='coerce')

# %% [markdown]
# #  Converting Quantity and Unit Price to Numeric Format

# %%
#  Convert the 'QUANTITY' column to a numeric integer type
df_sample['QUANTITY'] = pd.to_numeric(df_sample['QUANTITY'], downcast='integer')

#  Convert the 'UNIT_PRICE' column to a numeric float type
df_sample['UNIT_PRICE'] = pd.to_numeric(df_sample['UNIT_PRICE'], downcast='float')

# %% [markdown]
# # Converting SHIPMENT_SLA to Numeric and Calculating Shipping Delay

# %%
# Check if SHIPMENT_SLA is a string and convert it to numeric (assuming it's a number)
df_sample['SHIPMENT_SLA'] = pd.to_numeric(df_sample['SHIPMENT_SLA'], errors='coerce')

# Now calculate the shipping delay
df_sample['SHIPPING_DELAY'] = (df_sample['WM_SHIPPED_DATE'] - df_sample['ORDER_DATE']).dt.days > df_sample['SHIPMENT_SLA']

# %% [markdown]
# # Handling Missing Values in Shipping Delay and Date Columns

# %%
# Fill NaN values in SHIPPING_DELAY if necessary
df_sample['SHIPPING_DELAY'].fillna(False, inplace=True)  # Assuming False for missing data

# Ensure that date columns are in datetime format
df_sample['ORDER_DATE'] = pd.to_datetime(df_sample['ORDER_DATE'], errors='coerce')
df_sample['WM_SHIPPED_DATE'] = pd.to_datetime(df_sample['WM_SHIPPED_DATE'], errors='coerce')

# Fill missing date columns with a default value if necessary (e.g., using the current date or another business logic)
df_sample['WM_SHIPPED_DATE'].fillna(df_sample['ORDER_DATE'], inplace=True)  # Assuming shipped same as order date if missing

# %% [markdown]
# # Converting SHIPMENT_SLA and Handling Shipping Delay Calculation

# %%
# Ensure 'SHIPMENT_SLA' values are converted to numeric, coercing errors for non-numeric values
df_sample['SHIPMENT_SLA'] = pd.to_numeric(df_sample['SHIPMENT_SLA'], errors='coerce')

# Convert 'ORDER_DATE' and 'WM_SHIPPED_DATE' to datetime, coercing errors for invalid formats
df_sample['ORDER_DATE'] = pd.to_datetime(df_sample['ORDER_DATE'], errors='coerce')
df_sample['WM_SHIPPED_DATE'] = pd.to_datetime(df_sample['WM_SHIPPED_DATE'], errors='coerce')

# Assuming that if 'WM_SHIPPED_DATE' is missing, the order was shipped on the same day as the order was placed
df_sample['WM_SHIPPED_DATE'].fillna(df_sample['ORDER_DATE'], inplace=True)


# Calculate whether the actual shipping time (in days) exceeded the SLA, resulting in a shipping delay
df_sample['SHIPPING_DELAY'] = (df_sample['WM_SHIPPED_DATE'] - df_sample['ORDER_DATE']).dt.days > df_sample['SHIPMENT_SLA']

# Fill missing values in 'SHIPPING_DELAY' with False, assuming no delay if data is missing
df_sample['SHIPPING_DELAY'].fillna(False, inplace=True)

# %% [markdown]
# # Writing Pandas DataFrame to Snowflake Table

# %%
# Create a Snowflake DataFrame from the existing Pandas DataFrame (df) using the Snowflake session
training_datadf = my_session.createDataFrame(df_sample)

# Save the Snowflake DataFrame as a table named 'ORDER_DATA_TRAINING' in Snowflake
# The 'overwrite' mode ensures that the table is replaced if it already exists
training_datadf.write.mode("overwrite").save_as_table("ORDER_DATA_TRAINING")
